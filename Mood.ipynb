# %%
import pandas
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.style.use('seaborn-whitegrid')
import numpy as np
import pandas as pd

def make_plot(filename):
    data = pandas.read_csv(filename, usecols=[0,1,2])
    
    fig, ax = plt.subplots(figsize=[20,10])

    for k, v in data.iterrows():
        ax.annotate(v["Notes"], (k, v["Mood"]),
                xytext=(0,0), textcoords='offset points',
               fontsize=15, color='black',
               rotation=45)


    data.plot(kind="line" , yticks=[1,2,3,4,5,6], x="Time", ax=ax)

# %%
data
# Out:
#      Time  Mood                                             Notes
# 0    7:30     4                               energized and happy
# 1    8:30     4                              excited to start day
# 2    9:30     4                                 excited and happy
# 3   10:30     4                                            improv
# 4   11:30     4                                            improv
# 5   12:30     3                                             bored
# 6   13:30     4                                  voice over class
# 7   14:30     3                               physical discomfort
# 8   15:30     4  optimistic about new spots with voice over class
# 9   16:30     4                                          Top Golf
# 10  17:30     5                                        having fun
# 11  18:30     3                              felt sick to stomach
# 12  19:30     4                                             happy
# 13  20:30     4                                          learning
# 14  21:30     3                                             tired
# 15  22:30     3                                             tired

# %%
data.plot?

# %%
make_plot("mood_tuesday.csv")
make_plot("Weekly Mood Chart - Wednesday.csv")
make_plot("Weekly Mood Chart - Thursday.csv")
make_plot("Weekly Mood Chart - Friday.csv")
make_plot("Weekly Mood Chart - Saturday.csv")

# %%
make_plot("Weekly Mood Chart - Saturday.csv")
